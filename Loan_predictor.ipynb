# %%
import numpy as np
import pandas as pd
import sklearn as sl
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
loandf=pd.read_csv("loandataset.csv")

# %%
loandf.head(225)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 220  LP001736   Male     Yes          0      Graduate            No
# 221  LP001743   Male     Yes          2      Graduate            No
# 222  LP001744   Male      No          0      Graduate            No
# 223  LP001749   Male     Yes          0      Graduate            No
# 224  LP001750   Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
loandf.index
# Out:
# RangeIndex(start=0, stop=614, step=1)

# %%
loandf.describe(
)
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loandf.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loandf['Credit_History']=loandf['Credit_History'].fillna(loandf['Credit_History'].mean())

# %%
loandf['LoanAmount']=loandf['LoanAmount'].fillna(loandf['LoanAmount'].mean())

# %%
loandf.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loandf.replace({"Self_Employed":{'No':0,'Yes':1}},inplace=True)

# %%
loandf.replace({"Married":{'No':0,'Yes':1}},inplace=True)

# %%
loandf.replace({"Loan_Status":{'N':0,'Y':1}},inplace=True)

# %%
loandf['Self_Employed']=loandf['Self_Employed'].fillna(loandf['Self_Employed'].mean())

# %%
loandf.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loandf=loandf.replace(to_replace='3+',value=4)

# %%
loandf['Dependents']=loandf['Dependents'].fillna(4)

# %%
loandf['Loan_Amount_Term']=loandf['Loan_Amount_Term'].fillna(loandf['Loan_Amount_Term'].mean())

# %%
loandf.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loandf.head(225)
# Out:
#       Loan_ID Gender  Married Dependents     Education  Self_Employed  \
# 0    LP001002   Male      0.0          0      Graduate            0.0
# 1    LP001003   Male      1.0          1      Graduate            0.0
# 2    LP001005   Male      1.0          0      Graduate            1.0
# 3    LP001006   Male      1.0          0  Not Graduate            0.0
# 4    LP001008   Male      0.0          0      Graduate            0.0
# ..        ...    ...      ...        ...           ...            ...
# 220  LP001736   Male      1.0          0      Graduate            0.0
# 221  LP001743   Male      1.0          2      Graduate            0.0
# 222  LP001744   Male      0.0          0      Graduate            0.0
# 223  LP001749   Male      1.0          0      Graduate            0.0
# 224  LP001750   Male      1.0          0      Graduate            0.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loandf.replace({"Gender":{'Male':1,'Female':0}},inplace=True)

# %%
loandf.replace({"Education":{'Not Graduate':0,'Graduate':1}},inplace=True)

# %%
loandf.replace({"Property_Area":{'Rural':0,'Semiurban':1,'Urban':2}},inplace=True)

# %%
loandf['Married']=loandf['Married'].fillna(0)

# %%
loandf['Gender'].value_counts()
# Out:
# 1.0    489
# 0.0    112
# Name: Gender, dtype: int64

# %%
loandf['Gender']=loandf['Gender'].fillna(1)

# %%
loandf.head(223)
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0          0          1       0.000000
# 1    LP001003     1.0      1.0          1          1       0.000000
# 2    LP001005     1.0      1.0          0          1       1.000000
# 3    LP001006     1.0      1.0          0          0       0.000000
# 4    LP001008     1.0      0.0          0          1       0.000000
# ..        ...     ...      ...        ...        ...            ...
# 218  LP001732     1.0      1.0          2          1       0.140893
# 219  LP001734     0.0      1.0          2          1       0.000000
# 220  LP001736     1.0      1.0          0          1       0.000000
# 221  LP001743     1.0      1.0          2          1       0.000000
# 222  LP001744     1.0      0.0          0          1       0.000000
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# ...

# %%
loandf.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x=loandf.drop(columns=['Loan_ID','Loan_Status'],axis=1)
y=loandf['Loan_Status']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 x=loandf.drop(columns=['Loan_ID','Loan_Status'],axis=1)
#       2 y=loandf['Loan_Status']
#
# NameError: name 'loandf' is not defined

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.3,random_state=2)

# %%
x_train
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 222     1.0      0.0          0          1            0.0             2971
# 281     1.0      1.0          0          1            0.0             3927
# 372     1.0      1.0          2          1            1.0             9323
# 32      1.0      0.0          1          1            1.0             4692
# 204     1.0      1.0          2          0            0.0             3917
# ..      ...      ...        ...        ...            ...              ...
# 534     0.0      0.0          0          0            1.0            18165
# 584     1.0      1.0          1          1            0.0             2787
# 493     0.0      0.0          0          0            1.0            17263
# 527     1.0      1.0          1          0            0.0             5285
# 168     1.0      0.0          0          1            0.0             2237
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions=lr.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.76      0.33      0.46        39\n           1       0.75      0.95      0.84        84\n\n    accuracy                           0.76       123\n   macro avg       0.76      0.64      0.65       123\nweighted avg       0.76      0.76      0.72       123\n'

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,predictions)*100
# Out:
# 75.60975609756098
